# %%
import pandas as pd

# %%
df = pd.read_csv("results.csv")

# %%
df[df.target != df.canonicalName]
# Out:
#                                target                canonicalName  \
# 5                 Phytorus lineolatus                     Phytorus
# 26   Asterolecanium pseudolanceolatum               Asterolecanium
# 27           Asterolecanium coronatum               Asterolecanium
# 49                Aonidiella aurantii                   Aonidiella
# 54         Eudocima Othreis) fullonia                     Eudocima
# 65                  Nysius pulchellus                       Nysius
# 67             Brachyplatys insularis                 Brachyplatys
# 69                 Piezodorus hybneri                   Piezodorus
# 71             Coptosoma xanthogramma                    Coptosoma
# 82              Lamprosema diemenalis                   Lamprosema
# 88                 Heliothis armigera                    Heliothis
# 95                Marasmia venilialis                     Marasmia
# 112                     Agonoxena sp.                    Agonoxena
# ...
